# %% [markdown]
# Ques1. What is the difference between a function and a method in Python?
#
# Ans. The difference Between Methods and Function are as follows:
#
# - A function is a block of code (or statement) that performs a specific task and runs only when it is called. In contrast, methods in python are used to define the behavior of python object.
#
# - Method definition is always present inside the class, while the class is not required to define the function.
#
# - Functions can have a zero parameter, whereas the method should have a default parameter, either self or cls, to get the object.
#
# - The method operates the data in the class, while a function is used to return or pass the data.
#
# - A function can be directly called by its name, while a method can’t be called by its name.
#
# - The method lies under Object-Oriented Programming, while a function is an independent functionality.

# %% [markdown]
# Ques2. Explain the concept of function  arguments and parameters in Python.
#
# Ans. The terms parameter and argument can be used for the same thing: information that are passed into a function. The difference is that: Arguments are the variables passed to the function in the function call. Parameters are the variables like placeholder used in the function definition. The number of arguments and parameters should always be equal except for the variable length argument list.
#
# Example

# %%
# In this example, (num1, num2) are in the function call, and (a, b) are in the function definition.
#(num1, num2) are arguments and (a, b) are parameters.

def add_func(a,b):
    sum = a + b
    return sum
num1 = int(input("Enter the value of the first number: "))
num2 = int(input("Enter the value of the second number: "))
print("Sum of two numbers: ",add_func(num1, num2))
# Out:
# Enter the value of the first number: 2
# Enter the value of the second number: 3
# Sum of two numbers:  5

# %% [markdown]
# Ques 3. What are the different ways to define and call a function in Python?
#
# Ans. In programming, a function is a reusable block of code that executes a certain functionality when it is called. That means that a function is a piece of code written to carry out a specified task. To carry out that specific task, the function might or might not need multiple inputs. When the task is carried out, the function can or can not return one or more values.
#
# In Python we can define a function and call it depending upon the situation. Lets explain the different ways for defining a function and call of a function.
#
# 1. Function defination and call
# We can define a function using the def keyword, function name, parameter if needed, and the body of the function. Then we call the function with the corresponding arguments.

# %%
# A simple Python function
def sum_of_two_numbers(num1, num2):
  """Calculates the sum of two numbers and returns the result."""
  sum = num1 + num2
  return sum

# Call the function
result = sum_of_two_numbers(5, 10)

# Print the result
print("The sum is:", result)
# Out:
# The sum is: 8

# %% [markdown]
# Defining function with default argument:
#
# Here we provide default values for arguments while defining a function and making the function call optional for those arguments.

# %%
def greet_student(name):
  message = f"Welcome to the class of PWSkills, {name}!"
  print(message)

student_name = input("Please enter your name: ")
greet_student(student_name)
# Out:
# Please enter your name: bagmita
# Welcome to the class of PWSkills, bagmita!

# %% [markdown]
# 3.Defining function with keyword arguments:
# Here we pass arguments by name when calling the function

# %%
#Calculates the area of a triangle
def calculate_area(base, height):
  area =1/2 * base * height
  return area

# Using positional arguments
area1 = calculate_area(4, 7) # base = 4, height = 7
print(area1)

# Using keyword arguments
area2 = calculate_area(height=7, base=4)  # Same output, order of argument does not matter
print(area2)
# Out:
# 14.0
# 14.0

# %% [markdown]
# Defining a function with variable-length argument lists (args and kwargs):
#
# In Python, we can pass a variable number of arguments to a function using special symbols. There are two special symbols:
#
# *args (Non Keyword Arguments)
# **kwargs (Keyword Arguments)
#
# We use *args and **kwargs as an argument when we are not sure about the number of arguments to pass in the functions.
#
# Python has *args which allow us to pass the variable number of non keyword arguments to function

# %%
def adder(*num):
    sum = 0

    for n in num:
        sum = sum + n

    print("Sum:",sum)

adder(3,5)
adder(4,5,6,7)
adder(1,2,3,5,6)
# Out:
# Sum: 8
# Sum: 22
# Sum: 17

# %% [markdown]
#  In Python, **kwargs, allows to pass the variable length of keyword arguments to the function. That means The arguments are passed as a dictionary and these arguments make a dictionary inside function with name same as the parameter.

# %%
def doc1(**data):
    print("\nData type of argument:",type(data))

    for key, value in data.items():
        print("{} is {}".format(key,value))

doc1(Firstname="Yoshita", Lastname="Mohanty", Age=15, Phone=1234567890)
doc1(Firstname="Santosh", Lastname="Mohanty", Email="smohanty@hotmail.com", Country="India", Age=25, Phone=9876543210)
# Out:
# Data type of argument: <class 'dict'>
# Firstname is Yoshita
# Lastname is Mohanty
# Age is 15
# Phone is 1234567890
#
# Data type of argument: <class 'dict'>
# Firstname is Santosh
# Lastname is Mohanty
# Email is smohanty@hotmail.com
# Country is India
# Age is 25
# Phone is 9876543210

# %% [markdown]
# Ques. 4.what is the purpose of the `return` statement in a python function?
#
# Ans. The Python return statement marks the end of a function and specifies the value or values to pass back from the function. Return statements can return data of any type, including integers, floats, strings, lists, dictionaries, and even other functions.

# %% [markdown]
# Ques 5. What are iterators in Python and how do they differ from iterables?
#
# Ans. In Python, an iterator is an object that allows you to iterate over collections of data, such as lists, tuples, dictionaries, and sets. That means Iterators are defined as an object that counts iteration via an internal state variable. The variable, in this case, is NOT set to zero when the iteration crosses the last item, instead, StopIteration() is raised to indicate the end of the iteration.
#
# Iterators handle the process of accessing elements one at a time while iterables define the sequence of data. Iterators have both __iter__ (often implicit) and __next__ methods where as iterables have a __iter__ method. We can't directly iterate over an iterator using for loops, but one can use it to manually retrieve elements using __next__. Iterables, on the other hand, are directly usable in for loops because iter() is called behind the scenes.

# %% [markdown]
# Ques 6. Explain the concept of generators in Python and how they are defined.
#
# Ans. A generator is a function that returns an iterable set of values. Generators avoid creating a list or other data structure in memory to store the values as they are produced, instead replacing them one by one over time. This makes them more efficient than loops for large datasets and allows for code that runs in linear time.
#
# Generators are built using the yield keyword, which is used to indicate that a value should be returned from the function.
#
# Defining a generator
#
# - Define a function with the def keyword.
# - Use the yield keyword within the function body to produce a sequence of values.
# - The function becomes a generator when it contains yield.

# %%
def even_numbers(n):
  for i in range(n):
    if i % 2 == 0:
      yield i

# Get the generator object
even_generator = even_numbers(10)

# Iterate using a for loop
for num in even_generator:
  print(num)
# Out:
# 0
# 2
# 4
# 6
# 8

# %% [markdown]
# Ques 7. What are the advantages of using generators over regular functions?
#
# Ans. There are many advantages to using generators in Python, such as improved memory management, time savings, and flexibility. Generators can also produce infinite sequences and are more readable than traditional loops. Based on the following charecteristics one can use generator over fuction in Python:
#
#   Efficient - Python Generators are more efficient than loops for large datasets, as they produce values one by one instead of storing them in memory before returning them.
#   Memory Management - As generators produce values one by one rather than storing them in a list or other data structure, they also require less memory and can process large datasets without much RAM.
#   Time-Saving - Generators in Python can also save time as they do not need to wait for the entire sequence to be generated before returning them, allowing code to execute in linear time.
#   Infinite Sequences - Generators can produce infinite sequences, which is helpful for tasks such as stream processing or other activities requiring continuing input.
#   Flexibility - As generators can produce a sequence of values over time, they are incredibly versatile.

# %% [markdown]
# Ques 8.What is a lambda function in Python and when is it typically used?
#
# Ans. Lambda function is an anonymous function which does not have any name.A lambda function can take any number of arguments, but can only have one expression.
#
# Lambda Functions are typically used when:
#
# When you need a small, throwaway function for a quick calculation or manipulation.
# When a function requires another function as an argument, lambda functions provide a clean way to define that function inline without cluttering the code with named definitions.
# We can use lambda functions as key functions to sort lists based on custom criteria.
# With filter(), lambda functions can help filter elements from a sequence based on a specific condition.

# %% [markdown]
# Ques 9. Explain the purpose and usage of the `map()` function in Python.
#
# Ans. The map() function is used to execute a given function to each element of an iterable (such as lists, tuples, etc.).The map() function takes two arguments:
#
# Syntax:
# map(function, iterables)
#
# function - a function to which map passes each element of given iterable.
# iterables - iterables which is to be mapped such as lists, tuples, etc.

# %%
# program to returns the square of a numbers in a list
numbers = [2,4,6,8]
def square(number):
  return number * number

squared_numbers = map(square, numbers) # applying square() to each item of the numbers list
result = list(squared_numbers) #list for printing
print(result)
# Out:
# [4, 16, 36, 64]

# %% [markdown]
# Ques 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python.
#
# Ans. These are the built-in functions of Python and used in different ways to manipulate iterables like list, tuple etc in a different purpose, such as
#
# map() function is used to apply a given function to each element of an iterable and returns a new iterable with the results.
# filter() function is used to filter elements from an iterable based on a given condition or function and returns a new iterable with the filtered elements.
# reduce() function is used to apply a given function to the elements of an iterable in a cumulative way, reducing the iterable to a single value.
#
# In general, we can say that map() applies a given function to each item of an array and returns a new array where filter() creates a new array with all elements that pass a test implemented by the provided function. And reduce() applies a function against an accumulator and each element in the array (from left to right) to reduce it to a single output value.

# %%
# This prompt is asking to import the `reduce` function from the `functools` module
from functools import reduce
number = [47, 11, 42, 13]
sum = reduce(lambda x, y: x+y, number)
print ("sum of elements in ", number, "is :", sum)
# Out:
# sum of elements in  [47, 11, 42, 13] is : 113

# %% [markdown]
# In this example, we first imported the reduce() method from the functools module. We then defined a list of numbers and used the reduce() method to find their sum. We passed a lambda function as the first argument to the reduce() method. This lambda function takes two arguments x and y and returns their sum. The reduce() method applies this lambda function cumulatively to all elements in the list and returns their sum.

# %% [markdown]
# Practical Question
#
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

# %%
def sum_of_even_nums(numbers):
    even = 0
    for num in numbers:
        if num % 2 == 0 :
            even = even + num
    return even

list1 = input ("Enter the list of numbers with space or comma:")
numbers = [int (num) for num in list1.replace(',' , '').split()]
result = sum_of_even_nums(numbers)
print("Sum of even numbers in the list is: ", result)
# Out:
# Enter the list of numbers with space:4, 5, 9, 10
# Sum of even numbers in the list is:  14

# %% [markdown]
# 2. Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reverse_string(str1):
    return str1[:: -1]

str2 = input("Enter a String: ")
rev_str = reverse_string(str2)
print("Reverse of the string is :", rev_str)
# Out:
# Enter a String: hello
# Entered String is hello
# Reverse of the string is : olleh

# %% [markdown]
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

# %%
def square_of_numbers(numbers):
    return [num**2 for num in numbers]

list1 = input ("Enter the list of numbers with space or comma:")
numbers = [int (num) for num in list1.replace(',' , '').split()]
result1 = square_of_numbers(numbers)
print("Square of numbers in the list is: ", result1)
# Out:
# Enter the list of numbers with space or comma:2, 4, 6
# Square of numbers in the list is:  [4, 16, 36]

# %% [markdown]
#  4. Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def chk_prime(num):
  if num <= 1:
    return False
  if num <=3:
    return True
  for i in range(2, num):
    if num % i == 0 :
      return False
  return True

number = int(input("Enter a number between 1 to 200 "))
if 1<=number <=200 :
    if (chk_prime(number)):
       print("Prime number")
    else:
        print("Not a prime number")
else :
    print("Number is not between the defined range")
# Out:
# Enter a number between 1 to 200 81
# Not a prime number

# %% [markdown]
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

# %%
def fibonacci_series(n):
    fib_series_list = [0, 1]
    for i in range(2, n):
        fib_series_list.append(fib_series_list[-1] + fib_series_list[-2])
    return fib_series_list

# Example usage:
n = int(input(print("Enter a positive number")))
result = fibonacci_series(n)
print("Fibonacci series of ", n , "is :", result)

# %% [markdown]
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def power_generator(base, exponent):
    result = 1
    for i in range(exponent + 1):
        yield result
        result *= base

# Accept input from the user
base = int(input("Enter the base number: "))
exponent = int(input("Enter the exponent: "))

# Create the generator object
power_gen = power_generator(base, exponent)

# Generate and print the powers
print(f"Powers of {base} up to exponent {exponent}:")
for power in power_gen:
    print(power)
# Out:
# Enter the base number: 5
# Enter the exponent: 3
# Powers of 5 up to exponent 3:
# 1
# 5
# 25
# 125

# %% [markdown]
# 7. Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read_file_lines(file_path):
  """Reads a file line by line and yields each line as a string.

  Args:
    file_path: The path to the file to read.

  Yields:
    The next line in the file as a string.
  """

  with open(file_path, 'r') as file:
    for line in file:
      yield line.rstrip('\n')  # Remove trailing newline character

# Example usage:
file_path = 'your_file.txt'
for line in read_file_lines(file_path):
  print(line)

# %% [markdown]
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
my_list = [('a', 3), ('b', 1), ('c', 2)]

# Sort the list based on the second element of each tuple using lambda
sorted_list = sorted(my_list, key=lambda x: x[1])

print(sorted_list)
# Out:
# [('b', 1), ('c', 2), ('a', 3)]

# %% [markdown]
# 9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# %%
def convert(n):
  return (n*1.8)+32

celcious = [25, 17, 21, 32]
farenheit = map(convert, celcious)
print("Celious = ", list(celcious))
print("Converted to")
print("Farenheit : ", list(farenheit))
# Out:
# Celious =  [25, 17, 21, 32]
# Converted to
# Farenheit :  [77.0, 62.6, 69.80000000000001, 89.6]

# %% [markdown]
# 10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %%
vowel = ['a', 'e', 'i', 'o', 'u']
string1 = "Hello World"
print("Existing String is :", string1)
string1 = ''.join(filter(lambda i: i not in vowel, string1))
print("After removing the vowels: " + str(string1))
# Out:
# Existing String is : Hello World
# After removing the vowels: Hll Wrld

# %% [markdown]
# 11. Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this
#
# Order Number  Book Title& Author                Quantity    Priceperitem
# 34587         Learning Python, Mark Lutz            4           40.95
# 98762         Programming Python, Mark Lutz         5           56.80
# 77226         Head First Python, Paul Barry         3           32.95
# 88112         Einfuhrung in Python3, Bernd Klein    3           24.99
#
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the product of the price per item and the quantity. The product should be increased by 10,- € if the value of the order is smaller than 100,00 €.

# %%
def process_orders(orders):
    processed_orders = []
    for order in orders:
      order_number, _, quantity, price_per_item = order
      total_price = quantity * price_per_item
      if total_price < 100:
        total_price += 10
      processed_orders.append((order_number, quantity, total_price))
    return processed_orders
orders = [
  ["34587", "Learning Python, Mark Lutz", 4, 40.95],
  ["98762", "Programming Python, Mark Lutz", 5, 56.80],
  ["77226", "Head First Python, Paul Barry", 3, 32.95],
  ["88112", "Einfuhrung in Python3, Bernd Klein", 3, 24.99],
  ]
result = process_orders(orders)
print(result)
# Out:
# [('34587', 4, 163.8), ('98762', 5, 284.0), ('77226', 3, 108.85000000000001), ('88112', 3, 84.97)]

# %% [markdown]
# Write a Python program using lambda and map

# %%
def process_orders(orders):
    processed_orders = []
    for order in orders:
      order_number, _, _, quantity, price_per_item = order
      total_price = quantity * price_per_item
      if total_price < 100:
        total_price += 10
      processed_orders.append((order_number, quantity, total_price))
    return processed_orders
orders = [
["34587", "Learning Python, Mark Lutz", 4, 40.95],
["98762", "Programming Python, Mark Lutz", 5, 56.80],
["77226", "Head First Python, Paul Barry", 3, 32.95],
["88112", "Einfuhrung in Python3, Bernd Klein", 3, 24.99],
  ]
result = list(map(lambda order: (order[0],order[2], max(order[2] * order[3], order[2] * order[3] - 10)), orders))
print(result)
# Out:
# [('34587', 4, 163.8), ('98762', 5, 284.0), ('77226', 3, 98.85000000000001), ('88112', 3, 74.97)]
